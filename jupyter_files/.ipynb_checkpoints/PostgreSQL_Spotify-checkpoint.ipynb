# %%
import psycopg2 as pg2
import pandas as pd
from sqlalchemy import create_engine
import io

# %%
df = pd.read_csv('../spotify_data/data.csv')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df['artists'] = df['artists'].map(lambda x: x.strip('[\'').strip('\']'))

# %%
##clean df and remove all escape chars

# %%
to_remove = ''.join([chr(char) for char in range(1, 32)])
# Out:
# '\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x0c\r\x0e\x0f\x10\x11\x12\x13\x14\x15\x16\x17\x18\x19\x1a\x1b\x1c\x1d\x1e\x1f'

# %%
others = '\/,-&^%#@()'

# %%
to_remove = to_remove + others

# %%
to_remove
# Out:
# '\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x0c\r\x0e\x0f\x10\x11\x12\x13\x14\x15\x16\x17\x18\x19\x1a\x1b\x1c\x1d\x1e\x1f\\/,-&^%#@()'

# %%
translator = str.maketrans('', '', to_remove)

# %%
ndf = pd.DataFrame(columns=df.columns)

# %%
ndf.drop('Unnamed: 0',axis=1,inplace=True)

# %%
ndf.columns = ['name','artists','id', 'duration_ms', 'release_date' , 'acousticness', 'danceability', 'energy',
       'explicit',  'instrumentalness', 'key', 'liveness', 'loudness',
       'mode', 'popularity', 'speechiness', 'tempo',
       'valence', 'year']

# %%
clean_names =[]
for i in range(len(sdf)):
    clean_names.append(df.iloc[i]['name'].translate(translator))

# %%
clean_artists=[]
for i in range(len(sdf)):
    clean_artists.append(sdf.iloc[i]['artists'].replace("'",''))

# %%
clean_artists
# Out:
# ['Dennis Day',
#  'Sergei Rachmaninoff, James Levine, Berliner Philharmoniker',
#  'John McCormack',
#  'Sergei Rachmaninoff, James Levine, Berliner Philharmoniker',
#  'Phil Regan',
#  'Phil Regan',
#  'Sergei Rachmaninoff, Zubin Mehta, Vladimir Feltsman, Israel Philharmonic Orchestra',
#  'Frank Parker',
#  'Dennis Day',
#  'Sergei Rachmaninoff',
#  'Ignacio Corsini',
#  'Fortugé',
#  'Maurice Chevalier',
#  'Ignacio Corsini',
#  'Georgel',
#  'Mehmet Kemiksiz',
#  'Zay Gatsby',
#  'Sergei Rachmaninoff, Ruth Laredo',
#  'Hector Berlioz, Arturo Toscanini',
#  'THE GUY',
#  'Christopher Lynch',
#  'Fortugé',
#  'John McCormack, Edwin Schneider',
#  'Ignacio Corsini',
#  'Hanende İbrahim Efendi',
#  'Mehmet Kemiksiz',
#  'Sergei Rachmaninoff',
#  'Maurice Chevalier',
#  'Mehmet Kemiksiz',
#  'Fortugé',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Mehmet Kemiksiz',
#  'Mehmet Kemiksiz',
#  'Ermanno Wolf-Ferrari, Arturo Toscanini',
#  'Sergei Rachmaninoff, Ruth Laredo',
#  'Maurice Chevalier',
#  'THE GUY',
#  'Christopher Lynch',
#  'Mehmet Kemiksiz',
#  'Mehmet Kemiksiz',
#  'Dennis Day',
#  'Wolfgang Amadeus Mozart, Arturo Toscanini',
#  'Mehmet Kemiksiz',
#  'Ignacio Corsini',
#  'Sergei Rachmaninoff, Yuri Temirkanov, St. Petersburg Philharmonic Orchestra',
#  'Mehmet Kemiksiz',
#  'Felix Mendelssohn, Arturo Toscanini',
#  'Ignacio Corsini',
#  'Christopher Lynch',
#  'Morton Downey',
#  'Louis Boucot',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Mehmet Kemiksiz',
#  'Thomas Hallsten Paine',
#  'Ildebrando Pizzetti, Arturo Toscanini',
#  'Alice Cocéa',
#  'Sergei Rachmaninoff, Ruth Laredo',
#  'André Urban',
#  'Gaetano Donizetti, Arturo Toscanini',
#  'Mehmet Kemiksiz',
#  'Christopher Lynch',
#  'Mistinguett',
#  'Morton Downey',
#  'Darüttalim-i Musiki Heyeti',
#  'Hanende İbrahim Efendi',
#  'Maurice Chevalier',
#  'Sergei Rachmaninoff, Barry Douglas, Michael Tilson Thomas, London Symphony Orchestra',
#  'Ignacio Corsini',
#  'Marcelly',
#  'Sergei Rachmaninoff, Ruth Laredo',
#  'John McCormack',
#  'Ludwig van Beethoven, Arturo Toscanini',
#  'Sergei Rachmaninoff, Ruth Laredo',
#  'THE GUY',
#  'Ludwig van Beethoven, Arturo Toscanini',
#  'Georgius',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Sergei Rachmaninoff, Yuri Temirkanov, St. Petersburg Philharmonic Orchestra',
#  'Ignacio Corsini',
#  'Morton Downey',
#  'Mehmet Kemiksiz',
#  'Morton Downey',
#  'Ignacio Corsini',
#  'THE GUY',
#  'Robert Jysor',
#  'Safiye Ayla',
#  'Mistinguett',
#  'Sergei Rachmaninoff, Ruth Laredo',
#  'Christopher Lynch',
#  'THE GUY',
#  'Dennis Day',
#  'Ignacio Corsini',
#  'Maurice Chevalier',
#  'Sergei Rachmaninoff, János Starker',
#  'Fred Gouin',
#  'Ignacio Corsini',
#  'Uli',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Francis Marty',
#  'Mistinguett',
#  'Greg Fieler',
#  'Ignacio Corsini',
#  'Uli',
#  'Lucien Boyer',
#  'Félix Mayol',
#  'Victor Boucher',
#  'Ignacio Corsini',
#  'Jeanne Saint Bonnet',
#  'Luis Carlos Molina Acevedo',
#  'Ignacio Corsini',
#  'Adolphe Bérard',
#  'Louis Lynel',
#  'Ignacio Corsini',
#  'Perchicot',
#  'Perchicot',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Maurice Chevalier',
#  'Ignacio Corsini',
#  'Dréan',
#  'Mistinguett',
#  'Victor Boucher',
#  'Jim Chapman',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Adolphe Bérard',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Uli',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Adolphe Bérard',
#  'Ignacio Corsini',
#  'Georgius',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Félix Mayol',
#  'Ignacio Corsini',
#  'Fortugé',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Uli',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Uli',
#  'Georgius',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Mistinguett',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Jeanne Saint Bonnet',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Uli',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Fortugé',
#  'Georgius',
#  'Louis Armstrong, Earl Hines',
#  'Bessie Smith',
#  'Bessie Smith',
#  'Louis Armstrong',
#  'Bessie Smith',
#  'Bessie Smith',
#  'Bessie Smith, Louis Armstrong',
#  'Bessie Smith',
#  'Bessie Smith',
#  'Bessie Smith',
#  'Bessie Smith',
#  'Bessie Smith',
#  'Bessie Smith',
#  'Bessie Smith',
#  '"King Olivers Creole Jazz Band"',
#  'Bessie Smith, Louis Armstrong',
#  'Bessie Smith',
#  'Bessie Smith, Louis Armstrong',
#  'Bessie Smith',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  '"King Olivers Creole Jazz Band"',
#  'Bessie Smith',
#  'Bessie Smith',
#  'Bessie Smith',
#  'Louis Armstrong & His Hot Five',
#  'Bessie Smith',
#  'Bessie Smith',
#  'Louis Armstrong & His Hot Five',
#  '"King Olivers Creole Jazz Band"',
#  '"Clarence Williams Blue Five"',
#  'Bessie Smith',
#  'Louis Armstrong',
#  'Louis Armstrong & His Hot Seven',
#  'Louis Armstrong & His Sebastian New Cotton Club Orchestra',
#  'Jimmie Rodgers',
#  'Fletcher Henderson & His Orchestra',
#  'Louis Armstrong & His Hot Five',
#  '"Clarence Williams Blue Five"',
#  'Maggie Jones',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  '"Clarence Williams Blue Five"',
#  'Louis Armstrong & His Sebastian New Cotton Club Orchestra',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Sebastian New Cotton Club Orchestra',
#  'Hykoski Studios',
#  '"Clarence Williams Blue Five"',
#  'Louis Armstrong & His Hot Seven',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  '"Erskine Tates Vendome Orchestra"',
#  'Margaret Johnson',
#  'Louis Armstrong',
#  '"Carroll Dickersons Savoyagers"',
#  'Louis Armstrong',
#  '"Clarence Williams Blue Five"',
#  'Louis Armstrong',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Seven',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong',
#  'Fletcher Henderson & His Orchestra',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Maggie Jones',
#  'Louis Armstrong & His Hot Seven',
#  'Louis Armstrong',
#  'Fletcher Henderson & His Orchestra',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Bertha "Chippie" Hill, Louis Armstrong',
#  'Louis Armstrong & His Hot Five',
#  'Seger Ellis',
#  '"Clarence Williams Blue Five"',
#  'Louis Armstrong',
#  'Louis Armstrong & His Sebastian New Cotton Club Orchestra',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Louis Armstrong & His Hot Seven',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong',
#  'Nolan Welsh',
#  'The Southern Serenaders',
#  'Lillie Delk Christian',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Seven',
#  'Bertha "Chippie" Hill',
#  'Lillie Delk Christian',
#  'Hociel Thomas, Louis Armstrong',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Jean Goldkette and his Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Jean Goldkette and his Orchestra, Bix Beiderbecke',
#  'Jean Goldkette and his Orchestra, Bix Beiderbecke',
#  'Bix Beiderbecke, Hoagy Carmichael & His Orchestra',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke, Bing Crosby',
#  'Jean Goldkette and his Orchestra, Bix Beiderbecke',
#  'Bix Beiderbecke, Jean Goldkette and his Orchestra',
#  'Hoagy Carmichael & His Orchestra, Bix Beiderbecke, Bud Freeman',
#  'Bix Beiderbecke, Jean Goldkette and his Orchestra',
#  'Bix Beiderbecke, Hoagy Carmichael & His Orchestra',
#  'Hoagy Carmichael & His Orchestra, Bix Beiderbecke',
#  'Jean Goldkette and his Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Jean Goldkette and his Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke, Bing Crosby',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Jean Goldkette and his Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Concert Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Bix Beiderbecke And His Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bing Crosby, Bix Beiderbecke',
#  'Jean Goldkette and his Orchestra, Bix Beiderbecke',
#  'Bix Beiderbecke And His Orchestra, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Bix Beiderbecke, Bix Beiderbecke And His Orchestra',
#  'Paul Whiteman & His Orchestra, Bing Crosby, Bix Beiderbecke',
#  'Paul Whiteman & His Orchestra, Bix Beiderbecke',
#  'Bix Beiderbecke, Paul Whiteman & His Orchestra, Jack Fulton',
#  'Jean Goldkette and his Orchestra, Bix Beiderbecke',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'George Olsen',
#  'Francisco Canaro',
#  'The Chenille Sisters, "James Dapognys Chicago Jazz Band"',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Ignacio Corsini',
#  'The Chenille Sisters, "James Dapognys Chicago Jazz Band"',
#  'Ignacio Corsini',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Adolphe Bérard',
#  'Duke Ellington & His Washingtonians',
#  'The Chenille Sisters, "James Dapognys Chicago Jazz Band"',
#  'Hot Lips Page',
#  'Francisco Canaro',
#  'Georges Milton',
#  'Sara Gee & Ramblin Matt',
#  'Louis Armstrong',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Johann Sebastian Bach',
#  'Bayan Sultan',
#  'Francisco Canaro',
#  'The Chenille Sisters, "James Dapognys Chicago Jazz Band"',
#  'The Chenille Sisters, "James Dapognys Chicago Jazz Band"',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Mistinguett',
#  'George Olsen',
#  'Lionel Hampton Orchestra',
#  'Ignacio Corsini',
#  'Francisco Canaro',
#  'Fred Gouin',
#  'Georgius',
#  'René De Buxeuil',
#  'Francisco Canaro',
#  'Dranem',
#  'Francisco Canaro',
#  'George Olsen',
#  'Duke Ellington',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Lionel Hampton Orchestra',
#  'Maurice Chevalier',
#  'Francisco Canaro',
#  'Bessie Smith',
#  'George Olsen',
#  'Maurice Chevalier',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'George Olsen',
#  'Tommy Dorsey',
#  'Tommy Dorsey',
#  'Tommy Dorsey',
#  'Louis Armstrong & His Hot Five',
#  'Tommy Dorsey',
#  'Tommy Dorsey, Jack Leonard, Bunny Berigan',
#  'Louis Armstrong & His Hot Five',
#  'Tommy Dorsey',
#  'Ethel Waters',
#  'Tommy Dorsey',
#  'Tommy Dorsey',
#  'Louis Armstrong & His Hot Five',
#  'The Dorsey Brothers',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Five',
#  'Ethel Waters',
#  'Louis Armstrong & His Hot Five',
#  'Tommy Dorsey, Sy Oliver, Jo Stafford',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Five',
#  'Ethel Waters',
#  'Tommy Dorsey',
#  'Louis Armstrong & His Hot Five',
#  'Tommy Dorsey',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Five',
#  'The Big Aces',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Five',
#  'Tommy Dorsey, Edythe Wright',
#  'Paul Whiteman & His Orchestra',
#  'Tom Dorsey',
#  'Tommy Dorsey, Duke Ellington',
#  'Louis Armstrong & His Hot Five',
#  'The Boswell Sisters',
#  'Ethel Waters',
#  'Louis Armstrong & His Hot Five',
#  'Duke Ellington',
#  '"The Dorsey Brothers Orchestra"',
#  'The All-Star Orchestra',
#  'Louis Armstrong & His Hot Five',
#  'Sam Lanin & His Famous Players & Singers',
#  'Tommy Dorsey',
#  'Louis Armstrong & His Hot Five',
#  'Connie Boswell',
#  'The Golden Gate Orchestra',
#  'Tommy Dorsey',
#  'Tommy Dorsey',
#  'Bing Crosby',
#  'Ethel Waters',
#  'The Columbia Photo Players',
#  'Tommy Dorsey',
#  'Tommy Dorsey, Jimmy Dorsey',
#  'Tommy Dorsey',
#  'Louis Armstrong & His Hot Five',
#  'Tommy Dorsey & His Clambake Seven',
#  'Tommy Dorsey',
#  'Tommy Dorsey',
#  'Louis Armstrong & His Hot Five',
#  'The Travelers',
#  'Tommy Dorsey',
#  'Tommy Dorsey',
#  'Chick Bullock And His Levee Loungers',
#  'Louis Armstrong & His Hot Five',
#  'Tommy Dorsey',
#  'Tommy Dorsey',
#  'Ethel Waters',
#  'Ed Lang & His Orchestra',
#  'Tommy Dorsey',
#  'Tommy Dorsey',
#  'Jack Bland',
#  'Frank Sinatra, Tommy Dorsey Orchestra',
#  'Tommy Dorsey & His Clambake Seven',
#  'Tommy Dorsey',
#  'Tommy Dorsey & His Clambake Seven, Tommy Dorsey',
#  'Mildred Bailey',
#  'Art Jarrett',
#  'Tommy Dorsey',
#  'Louis Armstrong & His Hot Five',
#  'Ethel Waters',
#  'The Charleston Chasers',
#  'Tommy Dorsey, Elvis Presley',
#  'Tommy Dorsey',
#  'Louis Armstrong & His Hot Five',
#  'Harold Lem & His Orchestra',
#  'Tommy Dorsey',
#  'Ethel Waters',
#  'A Jam Session At Victor',
#  '"Test for Victor Young"',
#  'Tommy Dorsey',
#  'Hoagy Carmichael & His Orchestra',
#  'Tommy Dorsey',
#  'Tommy Dorsey & His Clambake Seven',
#  'Tommy Dorsey',
#  'Tommy Dorsey & His Clambake Seven, Edythe Wright',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'George Olsen',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Seven',
#  'Jelly Roll Morton, Johnny Dodds',
#  'Louis Armstrong & His Hot Seven',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'George Olsen',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Seven, Carroll Dickerson Orchestra',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Seven',
#  'Uncle Bunt Stephens',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Seven',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Louisiana Sugar Babes',
#  'Louis Armstrong & His Hot Seven',
#  'Fats Waller',
#  'Fats Waller',
#  'Louisiana Sugar Babes',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Seven',
#  'Fats Waller',
#  'Fats Waller, His Rhythm and Orchestra',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Seven',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Seven',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Seven',
#  'Louis Armstrong & His Hot Five',
#  'George Gershwin',
#  'Jack Teagarden And His Orchestra',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Seven',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Seven',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Fats Waller',
#  'Bunny Berigan, Tommy Dorsey, Fats Waller, Dick McDonough, George Wettling',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Louis Armstrong & His Hot Seven',
#  'Louis Armstrong & His Hot Seven',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Louis Armstrong & His Hot Five',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'Fats Waller',
#  'Louis Armstrong & His Hot Seven',
#  'Bix Beiderbecke',
#  'Bix Beiderbecke',
#  'Bix Beiderbecke',
#  'Bix Beiderbecke',
#  'Bix Beiderbecke, The Wolverines',
#  'Jimmie Rodgers, "Bob Sawyers Jazz Band"',
#  'Frankie Trumbauer & His Orchestra, Bix Beiderbecke',
#  'Frankie Trumbauer & His Orchestra, Bix Beiderbecke',
#  'Bix Beiderbecke',
#  'Ella Fitzgerald',
#  'Frank Trumbauer & His Orchestra, Bix Beiderbecke, Eddie Lang',
#  'Bix Beiderbecke',
#  'Frankie Trumbauer, Bix Beiderbecke, Eddie Lang',
#  'Frankie Trumbauer & His Orchestra, Bix Beiderbecke',
#  'Frankie Trumbauer & His Orchestra, Bix Beiderbecke',
#  'Frankie Trumbauer & His Orchestra, Bix Beiderbecke, Eddie Lang',
#  'Frankie Trumbauer & His Orchestra, Bix Beiderbecke, Eddie Lang',
#  'Frankie Trumbauer & His Orchestra, Bix Beiderbecke, Eddie Lang',
#  'Frankie Trumbauer & His Orchestra, Bix Beiderbecke, Eddie Lang',
#  'Broadway Bell Hops, Bix Beiderbecke, Frank Trumbauer',
#  'Dock Boggs',
#  'Broadway Bell Hops, Bix Beiderbecke, Frank Trumbauer',
#  'Benny Meroff & His Orchestra, Bix Beiderbecke',
#  'Bix Beiderbecke, The Wolverines',
#  'Benny Meroff & His Orchestra, Bix Beiderbecke',
#  'Bix Beiderbecke, The Wolverines',
#  'Bix Beiderbecke, The Wolverines',
#  'Baron Lee, The Blue Rhythm Band',
#  'Jimmie Rodgers',
#  'Bill "Bojangles" Robinson, Don Redman',
#  'Jimmie Rodgers',
#  'Bix Beiderbecke, The Wolverines',
#  'Tito Schipa',
#  'Bix Beiderbecke, The Wolverines',
#  'Bix Beiderbecke, The Wolverines',
#  'Jimmie Rodgers',
#  'Jimmie Rodgers',
#  'Bix Beiderbecke, The Wolverines',
#  'Jimmie Rodgers',
#  'Jimmie Rodgers',
#  'Tito Schipa',
#  'Francisco Canaro',
#  'Paul Bridgwater',
#  'Francisco Canaro',
#  'Sexteto Habanero',
#  'Francisco Canaro',
#  'Damia',
#  'Francisco Canaro',
#  'Cab Calloway & His Orchestra',
#  'Francisco Canaro',
#  'Ignacio Corsini',
#  'Francisco Canaro',
#  'Jimmie Rodgers',
#  'Francisco Canaro',
#  'Ignacio Corsini',
#  'Marty Murray',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Jimmie Rodgers',
#  'Ignacio Corsini',
#  'Francisco Canaro, Agustín Irusta',
#  'Orchestre Piero Coppola, José De Trévi, Lucy Perelli, Piero Coppola',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Paul Mania, Heinrich Schlusnus, Johann Heidenreich',
#  'Francisco Canaro',
#  'Numba 9',
#  'Orchestre Piero Coppola, Piero Coppola',
#  'Richard Wagner, Mitglieder der Staatskapelle Berlin, Max von Schillings',
#  'Georgius',
#  'Count Basie & His Orchestra; Vocal by Jimmy Rushing',
#  'Ignacio Corsini',
#  'Francisco Canaro',
#  'Orchestre Piero Coppola, Ch&#339;ur Piero Coppola, Piero Coppola',
#  'Francisco Canaro Jazz Band',
#  'Ignacio Corsini',
#  'Numba 9',
#  'Numba 9',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro, Agustín Irusta',
#  'Francisco Canaro',
#  'Numba 9',
#  'Ignacio Corsini',
#  'Francisco Canaro',
#  'Jimmie Rodgers',
#  'Ludwig van Beethoven, Staatskapelle Berlin, Otto Klemperer',
#  'Francisco Canaro',
#  'Francisco Canaro, Agustín Irusta',
#  'Ignacio Corsini',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Memphis Minnie',
#  'Pietro Mascagni, Staatskapelle Berlin',
#  'Tito Schipa',
#  'Francisco Canaro',
#  'Ignacio Corsini',
#  'Francisco Canaro',
#  'Ignacio Corsini',
#  'Numba 9',
#  'Benny Goodman',
#  'Blind Willie Johnson',
#  'Blind Willie Johnson',
#  'Benny Goodman, Peggy Lee',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Benny Goodman',
#  'Blind Willie Johnson',
#  'Blind Willie Johnson',
#  'Louis Armstrong & His Hot Five',
#  'Leroy Carr',
#  'Blind Willie Johnson',
#  'Louis Armstrong & His Hot Five',
#  'Blind Willie Johnson',
#  'Louis Armstrong & His Hot Seven',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Blind Willie Johnson',
#  'Frédéric Chopin, Vladimir Horowitz',
#  'Louis Armstrong & His Hot Five',
#  'Blind Willie Johnson',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Blind Willie Johnson',
#  'Louis Armstrong',
#  'Benny Goodman Sextet, Benny Goodman, Charlie Christian',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Louis Armstrong',
#  'Blind Willie Johnson',
#  'Blind Willie Johnson',
#  'Louis Armstrong',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Blind Willie Johnson',
#  'Blind Willie Johnson',
#  'Blind Willie Johnson',
#  'Benny Goodman Sextet, Charlie Christian',
#  'Louis Armstrong & His Hot Five',
#  'Bascom Lamar Lunsford',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong, Earl Hines',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Jimmy McPartland, Gil Rodin, Larry Binyon, Vic Briedis, Dick Morgan, Jack Teagarden, Ray Bauduc, Harry Goodman, Benny Goodman, "Jimmy Brackens Toe Ticklers"',
#  'William Warfield',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Louis Armstrong & His Hot Five',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Benny Goodman Quartet',
#  'Benny Goodman Sextet',
#  'Benny Goodman',
#  'Louis Armstrong & His Hot Seven',
#  'Blind Willie Johnson',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Louis Armstrong & His Hot Five',
#  'Benny Goodman Trio',
#  'Blind Willie Johnson',
#  'Louis Armstrong & His Hot Seven',
#  'Ted Lewis',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Jim Jackson',
#  'Benny Goodman Sextet, Benny Goodman, Charlie Christian',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Louis Armstrong',
#  'Frédéric Chopin, Vladimir Horowitz',
#  'Louis Armstrong',
#  'Louis Armstrong & His Hot Five',
#  'Benny Goodman',
#  'Louis Armstrong & His Hot Seven, Carroll Dickerson Orchestra',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Benny Goodman',
#  'Benny Goodman, Helen Ward',
#  'Louis Armstrong & His Hot Five',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Louis Armstrong & His Hot Five',
#  'Louis Armstrong & His Hot Seven, Carroll Dickerson Orchestra',
#  'Louis Armstrong & His Hot Five',
#  'Frédéric Chopin, Vladimir Horowitz',
#  'Louis Armstrong & His Hot Seven, Carroll Dickerson Orchestra',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Benny Goodman Sextet',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Leroy Carr',
#  'Louis Armstrong & His Hot Five',
#  'Benny Goodman',
#  'Louis Armstrong & His Hot Seven, Carroll Dickerson Orchestra',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Frédéric Chopin, Arthur Rubinstein',
#  'Benny Goodman Big Band',
#  'Louis Armstrong',
#  'Louis Armstrong & His Hot Seven, Carroll Dickerson Orchestra',
#  'Frédéric Chopin, Vladimir Horowitz',
#  'Louis Armstrong & His Hot Seven, Carroll Dickerson Orchestra',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Anita Darian, Louise Parker, The Merrill Staton Choir',
#  'Barbara Cook, John Raitt',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Memphis Minnie & Kansas Joe',
#  'Louis Armstrong',
#  'Louis Armstrong & His Sebastian New Cotton Club Orchestra',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Memphis Minnie',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Memphis Minnie',
#  'Louis Armstrong',
#  '"Prince Albert Hunts Texas Ramblers"',
#  'Memphis Minnie',
#  'Sergei Rachmaninoff, Leopold Stokowski',
#  'Frédéric Chopin, Vása Prihoda, Charles Cerné',
#  'Memphis Minnie',
#  'Memphis Minnie',
#  'Francisco Canaro, Charlo',
#  'Ignacio Corsini',
#  'Eugénie Buffet',
#  'Richard Strauss, Elisabeth Ohms, Adele Kern, Elfriede Marherr, Unknown Orchestra, Julius Pruwer',
#  'K.C.Dey',
#  'Francisco Canaro, Antonio Buglione',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro',
#  'Francisco Canaro, Charlo',
#  'André Baugé',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Memphis Minnie',
#  'Richard Strauss, London Philharmonic Orchestra',
#  'Carroll Gibbons',
#  'Carroll Gibbons',
#  'Ignacio Corsini',
#  'Francisco Canaro, Charlo',
#  'Ignacio Corsini',
#  'Gaston Gabaroche',
#  'Steve Correll Group',
#  'Carroll Gibbons',
#  'Memphis Minnie',
#  'Giuseppe Verdi, Julius Patzak, Unknown Orchestra, Manfred Gurlitt',
#  'Ignacio Corsini',
#  'Francisco Canaro, Charlo',
#  'Ludwig van Beethoven, Elisabeth Ohms, Unknown Orchestra, Manfred Gurlitt',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro',
#  'Mariano e Caçula',
#  'Francisco Canaro',
#  'Teodoro Cottrau, Umberto Urbano, Unknown Orchestra',
#  'Johann Strauss II, Margret Pfahl, Waldemar Henke, Willi Domgraf-Fassbaender, Staatskapelle Berlin, Hermann Weigert',
#  'Johann Strauss II, Margret Pfahl, Franz Völker, Leonard Kern, Staatskapelle Berlin, Hermann Weigert',
#  'Memphis Minnie',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Mistinguett',
#  'Johann Strauss II, Else Ruziczka, Adele Kern, Staatskapelle Berlin, Hermann Weigert',
#  'Francisco Canaro',
#  'Francisco Canaro, Ada Falcón',
#  'Ignacio Corsini',
#  'Mistinguett',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro',
#  'Perchicot',
#  'Montel',
#  'Memphis Minnie',
#  'Francisco Canaro, Charlo',
#  'Memphis Minnie',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Francisco Canaro, Charlo',
#  'Francisco Canaro, Charlo',
#  'Ignacio Corsini',
#  'Ignacio Corsini',
#  'Francisco Canaro',
#  'Francisco Canaro',
#  'Ignacio Corsini',
#  'Steve Correll Group',
#  'Johann Strauss II, Margret Pfahl, Adele Kern, Waldemar Henke, Willi Domgraf-Fassbaender, Staatskapelle Berlin, Hermann Weigert',
#  'Alessandra De Negri',
#  'Francisco Canaro, Charlo',
#  'Franz Liszt, Vladimir Horowitz',
#  'Franz Liszt, Vladimir Horowitz',
#  'The New Yorkers, Wilmouth Houdini, Eileen Barton',
#  'Franz Liszt, Vladimir Horowitz',
#  'Mississippi Sheiks',
#  'Carlos Gardel',
#  'Roaring Lion, Gerald Clark and his Caribbean Serenaders',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Jack Payne',
#  'Franz Liszt, Vladimir Horowitz',
#  'Franz Liszt, Vladimir Horowitz',
#  'Franz Liszt, Vladimir Horowitz',
#  'Al Bowlly',
#  'Big Bill Broonzy',
#  'Mississippi Sheiks',
#  'The Tiger',
#  'Big Bill Broonzy',
#  'Big Bill Broonzy',
#  'Louis Armstrong & His Hot Seven, Louis Armstrong',
#  'Mississippi Sheiks',
#  'Franz Liszt, Vladimir Horowitz',
#  'Al Bowlly',
#  'Franz Liszt, Vladimir Horowitz',
#  'Franz Liszt, Vladimir Horowitz',
#  'Louis Armstrong',
#  'Stuff Smith & His Onyx Club Boys',
#  'Louis Armstrong & His Sebastian New Cotton Club Orchestra',
#  'Big Bill Broonzy',
#  'Franz Liszt, Vladimir Horowitz',
#  'Louis Armstrong & His Sebastian New Cotton Club Orchestra',
#  'Franz Liszt, Vladimir Horowitz',
#  'Benny Goodman',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Franz Liszt, Vladimir Horowitz',
#  'Louis Armstrong',
#  'The Growler',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Mississippi Sheiks',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Sam Manning',
#  'Al Bowlly',
#  'Franz Liszt, Vladimir Horowitz',
#  'Franz Liszt, Vladimir Horowitz',
#  'Franz Liszt, Vladimir Horowitz',
#  '"Loveys Trinidad String Band"',
#  'Franz Liszt, Vladimir Horowitz',
#  'Marlene Dietrich',
#  'Franz Liszt, Vladimir Horowitz',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'George Symonette, The Native Bahamian Rhythms',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Phil Madison',
#  'Franz Liszt, Vladimir Horowitz',
#  'Franz Liszt, Vladimir Horowitz',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Francisco Alves, Mario Reis',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Franz Liszt, Vladimir Horowitz',
#  'Mississippi Sheiks',
#  'Louis Armstrong',
#  'Franz Liszt, Vladimir Horowitz',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Mississippi Sheiks',
#  'Franz Liszt, Vladimir Horowitz',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Franz Liszt, Vladimir Horowitz',
#  'Franz Liszt, Vladimir Horowitz',
#  'Louis Armstrong & His Sebastian New Cotton Club Orchestra',
#  'Franz Liszt, Vladimir Horowitz',
#  'Franz Liszt, Vladimir Horowitz',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Franz Liszt, Vladimir Horowitz',
#  'Mississippi Sheiks',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Joe Quartz',
#  'Al Bowlly',
#  'Franz Liszt, Vladimir Horowitz',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Louis Armstrong & His Savoy Ballroom Five',
#  'Franz Liszt, Vladimir Horowitz',
#  'Louis Armstrong',
#  'Franz Liszt, Vladimir Horowitz',
#  'Mississippi Sheiks',
#  'Louis Armstrong',
#  'Louis Armstrong',
#  'Franz Liszt, Vladimir Horowitz',
#  'Franz Liszt, Vladimir Horowitz',
#  'Jack Teagarden, Ben Pollack & His Orchestra',
#  'Franz Liszt, Vladimir Horowitz',
#  'Big Bill Broonzy',
#  'Louis Armstrong',
#  'Sexteto Habanero',
#  'Jack Payne, His BBC Dance Orchestra',
#  'Jack Payne, His BBC Dance Orchestra',
#  'Charlie Chaplin',
#  'Charlie Chaplin',
#  'Jack Payne, His BBC Dance Orchestra',
#  'Jack Payne, His BBC Dance Orchestra',
#  'Charlie Chaplin',
#  'Jack Payne, His BBC Dance Orchestra',
#  'Clarence Ashley',
#  'Jack Payne, His BBC Dance Orchestra',
#  'K Mullick',
#  'K Mullick',
#  'Francisco Canaro',
#  'Zofia Dromlewiczowa',
#  'Umm Kulthum',
#  'Angurbala Devi',
#  'Ninon Vallin, Georges Thill, Germaine Féraldy, "Chœur et Orchestre de lOpéra de Paris", Elie Cohen',
#  'Dranem',
#  'Clarence Ashley y Gwen Foster',
#  'Francisco Canaro, Charlo, Ada Falcón',
#  'Sures Babu',
#  'Jack Payne, His BBC Dance Orchestra',
#  'Sexteto Habanero',
#  'Ninon Vallin, Georges Thill, Germaine Féraldy, "Chœur et Orchestre de lOpéra de Paris", Elie Cohen',
#  'Francisco Canaro, Charlo',
#  'Zofia Dromlewiczowa',
#  'Zofia Dromlewiczowa',
#  ...]

# %%
ndf['name'] = clean_names

# %%
ndf['artists'] = clean_artists

# %%
for i in range(2,len(ndf.columns)):
    ndf[ndf.columns[i]] = df[df.columns[i]]

# %%
sum(ndf['id'] == df['id']) == len(ndf)
# Out:
# True

# %%
df = pd.read_csv('../spotify_data/data.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
cols = ndf.columns

# %%
ndf.to_csv('../spotify_data/cleaned_df.csv')

# %%
try:
    conn = psycopg2.connect(database ='SpotifyData', user='postgres', host='localhost', password='giao')
except:
    print("I am unable to connect to the database")
# Out:
# I am unable to connect to the database

# %%
cur = conn.cursor()

# %%
sdf
# Out:
#                                                      name  \
# 0                                 Clancy Lowered the Boom
# 1       Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 2                                The Wearing of the Green
# 3       Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 4                             When Irish Eyes Are Smiling
# ...                                                   ...
# 168587                                        Born to Die
# 168588                                                Man
# 168589                                             Rivers
# 168590                                               0.00
# 168591                              Morocco (feat. 6LACK)
#
#                                                   artists  \
# 0                                              Dennis Day
# 1       Sergei Rachmaninoff', 'James Levine', 'Berline...
# 2                                          John McCormack
# 3       Sergei Rachmaninoff', 'James Levine', 'Berline...
# 4                                              Phil Regan
# ...                                                   ...
# 168587                                     Kelly Clarkson
# 168588                                               JoJo
# 168589                                         S.J Morgan
# 168590                                   Childish Gambino
# 168591                               Alina Baraz', '6LACK
#
#                             id
# 0       7xPhfUan2yNtyFG0cUWkt8
# 1       4BJqT0PrAfrxzMOxytFOIz
# 2       5uNZnElqOS3W4fRmRYPk4T
# 3       1SCWBjhk5WmXPxhDduD3HM
# 4       4d6HGyGT8e121BsdKmw9v6
# ...                        ...
# 168587  5Y5b0wokJqZxaefDVRm43v
# 168588  7wrBKecywD6TUuHQl3wjmj
# 168589  67zZV7JzIx9Wcf65Ztt4CJ
# 168590  4Ksj9mKfsYC5b8v8Ey3c8I
# 168591  1fm1PmtAvxXe98n8xOcKnJ
#
# [168592 rows x 3 columns]

# %%
## Adds df to database 

engine = create_engine('postgresql+psycopg2://postgres:giao@localhost/SpotifyData')

sdf.head(0).to_sql('simplesong', engine, if_exists='replace',index=False) #truncates the table

conn = engine.raw_connection()
cur = conn.cursor()
output = io.StringIO()
sdf.to_csv(output, sep='\t', header=False, index=False)
output.seek(0)
contents = output.getvalue()
cur.copy_from(output, 'simplesong', null="") # null values become ''
conn.commit()

# %%
sdf.iloc[66994]['name'] = "Piano Sonata No. 15"
sdf.iloc[66994]['artists'] = "Ludwig van Beethoven"

# %%
sdf.iloc[149595]['name'] = "Pay It Back"

# %%
sdf
# Out:
#                                                      name  \
# 0                                 Clancy Lowered the Boom
# 1       Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 2                                The Wearing of the Green
# 3       Piano Concerto No. 3 in D Minor, Op. 30: III. ...
# 4                             When Irish Eyes Are Smiling
# ...                                                   ...
# 168587                                        Born to Die
# 168588                                                Man
# 168589                                             Rivers
# 168590                                               0.00
# 168591                              Morocco (feat. 6LACK)
#
#                                                   artists  \
# 0                                              Dennis Day
# 1       Sergei Rachmaninoff', 'James Levine', 'Berline...
# 2                                          John McCormack
# 3       Sergei Rachmaninoff', 'James Levine', 'Berline...
# 4                                              Phil Regan
# ...                                                   ...
# 168587                                     Kelly Clarkson
# 168588                                               JoJo
# 168589                                         S.J Morgan
# 168590                                   Childish Gambino
# 168591                               Alina Baraz', '6LACK
#
#                             id
# 0       7xPhfUan2yNtyFG0cUWkt8
# 1       4BJqT0PrAfrxzMOxytFOIz
# 2       5uNZnElqOS3W4fRmRYPk4T
# 3       1SCWBjhk5WmXPxhDduD3HM
# 4       4d6HGyGT8e121BsdKmw9v6
# ...                        ...
# 168587  5Y5b0wokJqZxaefDVRm43v
# 168588  7wrBKecywD6TUuHQl3wjmj
# 168589  67zZV7JzIx9Wcf65Ztt4CJ
# 168590  4Ksj9mKfsYC5b8v8Ey3c8I
# 168591  1fm1PmtAvxXe98n8xOcKnJ
#
# [168592 rows x 3 columns]

# %%
sdf[sdf['name']=='Santa Lucia']
# Out:
#                name                                            artists  \
# 23565   Santa Lucia                                         Jerry Vale
# 66993   Santa Lucia  Anonymous\xa0', 'Mario Lanza', 'Constantine Ca...
# 116883  Santa Lucia                                     Connie Francis
# 123752  Santa Lucia  Anonymous\xa0', 'Mario Lanza', 'Constantine Ca...
#
#                             id
# 23565   6A4eiTRZukwEhjU6eIqQsg
# 66993   0a3HTDNbZoonLnmY0EafMR
# 116883  2NcXxWTkh49Dm0vi5YYyE8
# 123752  33APMPi0Q5dkHNeu0fi9vK

# %%
sdf.iloc[123752]['artists'] = "'Mario Lanza', 'Constantine Callinicos'"

# %%
sdf.iloc[123752]['artists']
# Out:
# "'Mario Lanza', 'Constantine Callinicos'"

# %%
for i in range(len(sdf)):
    sdf.iloc[i]['artists'] = sdf.iloc[i]['artists'].translate(translator)

# %%
sdf.iloc[72434]['artists']
# Out:
# "blink-182', 'Robert Smith"

# %%
escapes
# Out:
# '\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\x0c\r\x0e\x0f\x10\x11\x12\x13\x14\x15\x16\x17\x18\x19\x1a\x1b\x1c\x1d\x1e\x1f !"#$'

# %%
escapes = ''.join([chr(char) for char in range(1, 32)])

# %%
translator = str.maketrans('', '', escapes)

# %%
t = s.translate(None, escapes)
