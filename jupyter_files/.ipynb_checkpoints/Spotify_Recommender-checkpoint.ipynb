# %%
import pandas as pd 
import numpy as np
import spotipy 
sp = spotipy.Spotify() 
from spotipy.oauth2 import SpotifyClientCredentials 
cid ="af2697ff1adb4b4baa20e069e032c4dd" 
secret = "c27d4eb2db9945a0b1a4944f77519414" 
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 
sp.trace=False

# %%
usr_id = "walshale?si=E3OL1EZQRwaZV7VGUdGtug"
me = sp.user(usr_id)

# %%
#https://open.spotify.com/playlist/37i9dQZF1DX2Nc3B70tvx0?si=Pq3TWKwHQ9ilOCz-MVlPNA
ultimate_indie_uri = "spotify:playlist:37i9dQZF1DX2Nc3B70tvx0"

# %%
ultimate_indie = sp.playlist(playlist_id=ultimate_indie_uri)
type(ultimate_indie)
# Out:
# dict

# %%
ultimate_indie["tracks"]['items'][2]['track']["available_markets"]
# Out:
# ['CA', 'MX', 'US']

# %%
for i in range(len(ultimate_indie["tracks"]['items'])):
    try:
        del ultimate_indie["tracks"]['items'][i]['track']["available_markets"]
    except:
        print("not found in "+i)
        pass
    try: 
        del ultimate_indie["tracks"]['items'][i]['track']['album']["available_markets"]
    except:
        print("also not found in "+i)
        pass

# %%
ultimate_indie["tracks"]['items'][2]
# Out:
# {'added_at': '2020-05-15T08:01:00Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': '#af9d40',
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Ui2kfOqGujY81UcPrb5KE'},
#      'href': 'https://api.spotify.com/v1/artists/4Ui2kfOqGujY81UcPrb5KE',
#      'id': '4Ui2kfOqGujY81UcPrb5KE',
#      'name': 'HAIM',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Ui2kfOqGujY81UcPrb5KE'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4veKZd8uf7TDVo1KQRVhuk'},
#    'href': 'https://api.spotify.com/v1/albums/4veKZd8uf7TDVo1KQRVhuk',
#    'id': '4veKZd8uf7TDVo1KQRVhuk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734847cf25090d3ddabddfe83c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024847cf25090d3ddabddfe83c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514847cf25090d3ddabddfe83c',
#      'width': 64}],
#    'name': 'I Know Alone',
#    'release_date': '2020-04-29',
#    'release_date_precision': 'day',
#    'total_tracks': 5,
#    'type': 'album',
#    'uri': 'spotify:album:4veKZd8uf7TDVo1KQRVhuk'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Ui2kfOqGujY81UcPrb5KE'},
#     'href': 'https://api.spotify.com/v1/artists/4Ui2kfOqGujY81UcPrb5KE',
#     'id': '4Ui2kfOqGujY81UcPrb5KE',
#     'name': 'HAIM',
#     'type': 'artist',
#     'uri': 'spotify:artist:4Ui2kfOqGujY81UcPrb5KE'}],
#   'disc_number': 1,
#   'duration_ms': 226026,
#   'episode': False,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM72000500'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7CbxeQuHA0uysmwrbuWoSI'},
#   'href': 'https://api.spotify.com/v1/tracks/7CbxeQuHA0uysmwrbuWoSI',
#   'id': '7CbxeQuHA0uysmwrbuWoSI',
#   'is_local': False,
#   'name': 'I Know Alone',
#   'popularity': 64,
#   'preview_url': 'https://p.scdn.co/mp3-preview/804c3689f0b7a5df84e27ad4ff441b14e2943723?cid=af2697ff1adb4b4baa20e069e032c4dd',
#   'track': True,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:7CbxeQuHA0uysmwrbuWoSI'},
#  'video_thumbnail': {'url': None}}

# %%
#arist
ultimate_indie["tracks"]["items"][0]["track"]['artists'][0]["name"]
# Out:
# 'Jelani Aryeh'

# %%
#title
ultimate_indie["tracks"]["items"][0]["track"]["name"]
# Out:
# 'Stella Brown'

# %%
#popularity
ultimate_indie["tracks"]["items"][0]["track"]["popularity"]
# Out:
# 63

# %%
first_id = ultimate_indie["tracks"]["items"][0]["track"]["id"]

# %%
feats = sp.audio_features(first_id)[0]

# %%
ultimate_indie['tracks']['items'][1]["track"]["id"]
# Out:
# '6Md0VfGaWXZgJc53IMqPkO'

# %%
def get_playlist_audioFeats(playlist_id):
    """
    Returns a pandas.df of all audio features within a playlist
    From spotify playlist uri
    """
    playlist = sp.playlist(playlist_id=playlist_id)['tracks']['items']
    ids = []
    song_attr = []
    for song in playlist:
        try:
            ids.append(song['track']['id'])
            title = song["track"]["name"]
            artist = song["track"]["artists"][0]['name']
            popularity = song["track"]["popularity"]
            songinfo = {"title":title,"artist":artist,"popularity":popularity}
            song_attr.append(songinfo)
        except TypeError:
            pass
        
    features = sp.audio_features(ids)
    for i in range(len(song_attr)):
        song_attr[i].update(features[i])
    
    df = pd.DataFrame(song_attr)
    drop_list = ["type","uri","track_href","analysis_url"]
    df.drop(drop_list,axis=1,inplace=True)
    return df

# %%
result = get_playlist_audioFeats(ultimate_indie_uri)

# %%
result[result['time_signature']==5]
# Out:
#        title         artist  popularity  danceability  energy  key  loudness  \
# 6  Dreamland  Glass Animals          69         0.253   0.352    8   -11.509
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 6     1       0.0357         0.883           0.00191    0.0668    0.099
#
#     tempo                      id  duration_ms  time_signature
# 6  141.97  5Bkw0lMhwk8tF4kMgCCJLv       203492               5

# %%
result.sort_values(by='danceability',axis=0,ascending=False)
# Out:
#                                title                    artist  popularity  \
# 65                        In My Room               Frank Ocean          75
# 64  I disappear in your arms - bonus  Christine and the Queens          59
# 86                           Karaoke               Ginger Root          42
# 27                  Hold It Together                The Marías          61
# 44                     Funky Galileo                 Sure Sure          56
# ..                               ...                       ...         ...
# 98                            Garden               Ambar Lucid          43
# 1                              PDLIF                  Bon Iver          68
# 60       Music to Clean the House to                 Nick Leng          45
# 50                         peacefall               Purity Ring          29
# 6                          Dreamland             Glass Animals          69
#
#     danceability  energy  key  loudness  mode  speechiness  acousticness  ...  \
# 65         0.861   0.647    7    -7.425     1       0.0675        0.5940  ...
# 64         0.817   0.566    7    -6.928     1       0.0366        0.0471  ...
# 86         0.802   0.786   11    -5.134     0       0.0335        0.2590  ...
# 27         0.802   0.494   11   -10.099     0       0.0590        0.4280  ...
# 44         0.802   0.325   10    -9.327     1       0.0466        0.1640  ...
# ..           ...     ...  ...       ...   ...          ...           ...  ...
# 98         0.361   0.449    9    -8.962     0       0.0350        0.4210  ...
# 1          0.328   0.461    6    -8.790     1       0.0434        0.4470  ...
# 60         0.320   0.485    1    -8.125     0       0.0306        0.0614  ...
# 50         0.267   0.637    7    -9.803     0       0.0424        0.2560  ...
# 6          0.253   0.352    8   -11.509     1       0.0357        0.8830  ...
#
#     liveness  valence    tempo            type                      id  \
# 65    0.1140    0.670  158.037  audio_features  4S4Mfvv03M1cHgIOJcbUCL
# 64    0.0816    0.372  119.991  audio_features  7k9L8N0jZcz9qFupVeI4Va
# 86    0.1240    0.851  118.023  audio_features  5vs3gwBqp1jJD82dZG8v4Z
# 27    0.1070    0.518   82.014  audio_features  6gJ2H930mAD1zRqmoFiE4W
# 44    0.1560    0.648  110.995  audio_features  0TAHhMjG17P5pzlSm1sgSl
# ..       ...      ...      ...             ...                     ...
# 98    0.1040    0.240  149.626  audio_features  5PF6ojt1ENjE53qWKjT2Kn
# 1     0.1550    0.232  126.015  audio_features  6Md0VfGaWXZgJc53IMqPkO
# 60    0.1810    0.155   79.769  audio_features  7doJTm33FOrVlGJVybeM5T
# 50    0.2170    0.115   76.816  audio_features  0u0i25AJrwbmfIDjgYsoA9
# 6     0.0668    0.099  141.970  audio_features  5Bkw0lMhwk8tF4kMgCCJLv
#
#                                      uri  \
# 65  spotify:track:4S4Mfvv03M1cHgIOJcbUCL
# 64  spotify:track:7k9L8N0jZcz9qFupVeI4Va
# 86  spotify:track:5vs3gwBqp1jJD82dZG8v4Z
# 27  spotify:track:6gJ2H930mAD1zRqmoFiE4W
# 44  spotify:track:0TAHhMjG17P5pzlSm1sgSl
# ..                                   ...
# 98  spotify:track:5PF6ojt1ENjE53qWKjT2Kn
# 1   spotify:track:6Md0VfGaWXZgJc53IMqPkO
# 60  spotify:track:7doJTm33FOrVlGJVybeM5T
# 50  spotify:track:0u0i25AJrwbmfIDjgYsoA9
# 6   spotify:track:5Bkw0lMhwk8tF4kMgCCJLv
#
#                                            track_href  \
# 65  https://api.spotify.com/v1/tracks/4S4Mfvv03M1c...
# 64  https://api.spotify.com/v1/tracks/7k9L8N0jZcz9...
# 86  https://api.spotify.com/v1/tracks/5vs3gwBqp1jJ...
# 27  https://api.spotify.com/v1/tracks/6gJ2H930mAD1...
# 44  https://api.spotify.com/v1/tracks/0TAHhMjG17P5...
# ..                                                ...
# 98  https://api.spotify.com/v1/tracks/5PF6ojt1ENjE...
# 1   https://api.spotify.com/v1/tracks/6Md0VfGaWXZg...
# 60  https://api.spotify.com/v1/tracks/7doJTm33FOrV...
# 50  https://api.spotify.com/v1/tracks/0u0i25AJrwbm...
# 6   https://api.spotify.com/v1/tracks/5Bkw0lMhwk8t...
#
#                                          analysis_url duration_ms  \
# 65  https://api.spotify.com/v1/audio-analysis/4S4M...      133680
# 64  https://api.spotify.com/v1/audio-analysis/7k9L...      236375
# 86  https://api.spotify.com/v1/audio-analysis/5vs3...      237822
# 27  https://api.spotify.com/v1/audio-analysis/6gJ2...      222022
# 44  https://api.spotify.com/v1/audio-analysis/0TAH...      246200
# ..                                                ...         ...
# 98  https://api.spotify.com/v1/audio-analysis/5PF6...      214970
# 1   https://api.spotify.com/v1/audio-analysis/6Md0...      177286
# 60  https://api.spotify.com/v1/audio-analysis/7doJ...      225733
# 50  https://api.spotify.com/v1/audio-analysis/0u0i...      256733
# 6   https://api.spotify.com/v1/audio-analysis/5Bkw...      203492
#
#     time_signature
# 65               4
# 64               4
# 86               4
# 27               4
# 44               4
# ..             ...
# 98               4
# 1                4
# 60               4
# 50               4
# 6                5
#
# [100 rows x 21 columns]

# %%
import seaborn as sns

# %%
sns.heatmap(result.corr())

# %%
result.corrwith(result['popularity'],axis=0).sort_values(ascending=False)
# Out:
# popularity          1.000000
# danceability        0.174674
# tempo               0.138547
# duration_ms         0.132599
# instrumentalness    0.116161
# acousticness        0.097967
# time_signature      0.090726
# mode                0.054103
# speechiness         0.017626
# valence             0.006062
# liveness           -0.090653
# key                -0.096710
# loudness           -0.104143
# energy             -0.224470
# dtype: float64

# %%
## Get a bunch of data info from indie playlists

IndiePlaylists = {
    "All_new_indie": "spotify:playlist:37i9dQZF1DXdbXrPNafg9d",
    "Pollen": "spotify:playlist:37i9dQZF1DWWBHeXOYZf74",
    "BedroomPop": "spotify:playlist:37i9dQZF1DXcxvFzl58uP7",
    "Lorem" : "spotify:playlist:37i9dQZF1DXcxvFzl58uP7",
    "IndiePop" : "spotify:playlist:37i9dQZF1DWWEcRhUVtL8n",
    "Feelgoodindierock" : "spotify:playlist:37i9dQZF1DX2sUQwD7tbmL",
    "idk" : "spotify:playlist:37i9dQZF1DX59NCqCqJtoH",
    "SurfRockSunshine" : "spotify:playlist:37i9dQZF1DWYzpSJHStHHx",
    "LateNightVibes" : "spotify:playlist:37i9dQZF1DXdQvOLqzNHSW",
    "Alternitie10s" : "spotify:playlist:37i9dQZF1DX873GaRGUmPl",
    "IndiePop2000s":"spotify:playlist:37i9dQZF1DX9LbdoYID5v7",
    "IndiePop2010s":"spotify:playlist:37i9dQZF1DXaLaoaQqrfyO",
    "EarlyAlternitive":"spotify:playlist:37i9dQZF1DXdTCdwCKzXwo",
    "HyperPop":"spotify:playlist:37i9dQZF1DX7HOk71GPfSw",
    "ModernPsychedila":"spotify:playlist:37i9dQZF1DX8gDIpdqp1XJ",
    "EssentialIndie":"spotify:playlist:37i9dQZF1DX26DKvjp0s9M",
    "Alternitive90s":"spotify:playlist:37i9dQZF1DXaLI8a395lse",
    "IndieChillout":"spotify:playlist:37i9dQZF1DX9B1hu73DioC",
    "ChoiceEdit":"spotify:playlist:37i9dQZF1DX1aTyQ3Z9nTc",
    "SadIndie":"spotify:playlist:37i9dQZF1DWVV27DiNWxkR",
    "Alternative000s":"spotify:playlist:37i9dQZF1DX0YKekzl0blG",
    "Altar":"spotify:playlist:37i9dQZF1DXa71eg5j9dKZ",
    "Undercurrents":"spotify:playlist:37i9dQZF1DX9myttyycIxA",
    "ShoegazeBeyond":"spotify:playlist:37i9dQZF1DX6ujZpAN0v9r",
    "IndieCovers":"spotify:playlist:37i9dQZF1DXb67OkZ6150Z"
}

# %%
for playlist in IndiePlaylists.values():
# Out:
# spotify:playlist:37i9dQZF1DXdbXrPNafg9d
# spotify:playlist:37i9dQZF1DWWBHeXOYZf74
# spotify:playlist:37i9dQZF1DXcxvFzl58uP7
# spotify:playlist:37i9dQZF1DXcxvFzl58uP7
# spotify:playlist:37i9dQZF1DWWEcRhUVtL8n
# spotify:playlist:37i9dQZF1DX2sUQwD7tbmL
# spotify:playlist:37i9dQZF1DX59NCqCqJtoH
# spotify:playlist:37i9dQZF1DWYzpSJHStHHx
# spotify:playlist:37i9dQZF1DXdQvOLqzNHSW
# spotify:playlist:37i9dQZF1DX873GaRGUmPl
# spotify:playlist:37i9dQZF1DX9LbdoYID5v7
# spotify:playlist:37i9dQZF1DXaLaoaQqrfyO
# spotify:playlist:37i9dQZF1DXdTCdwCKzXwo
# spotify:playlist:37i9dQZF1DX7HOk71GPfSw
# spotify:playlist:37i9dQZF1DX8gDIpdqp1XJ
# spotify:playlist:37i9dQZF1DX26DKvjp0s9M
# spotify:playlist:37i9dQZF1DXaLI8a395lse
# spotify:playlist:37i9dQZF1DX9B1hu73DioC
# spotify:playlist:37i9dQZF1DX1aTyQ3Z9nTc
# spotify:playlist:37i9dQZF1DWVV27DiNWxkR
# spotify:playlist:37i9dQZF1DX0YKekzl0blG
# spotify:playlist:37i9dQZF1DXa71eg5j9dKZ
# spotify:playlist:37i9dQZF1DX9myttyycIxA
# spotify:playlist:37i9dQZF1DX6ujZpAN0v9r
# spotify:playlist:37i9dQZF1DXb67OkZ6150Z

# %%
def Scrape_Playlist_Data(playlists):
    """
    Takes in a dictionary of playlist names as keys and uris as values
    returns dataframe of audio data on all playlists, 
    removes duplicate tracks
    """
    playlist_info = []
    for pl in playlists.values():
        playlist_info.append(get_playlist_audioFeats(pl))
        print(pl)
    df = pd.concat(playlist_info)
    df.drop_duplicates(inplace=True)
    df.reset_index(inplace=True)
    df.drop("index",axis=1,inplace=True)

    return df

# %%
df = Scrape_Playlist_Data(IndiePlaylists)
# Out:
# spotify:playlist:37i9dQZF1DXdbXrPNafg9d
# spotify:playlist:37i9dQZF1DXcxvFzl58uP7
# spotify:playlist:37i9dQZF1DXcxvFzl58uP7
# spotify:playlist:37i9dQZF1DWWEcRhUVtL8n
# spotify:playlist:37i9dQZF1DX2sUQwD7tbmL
# spotify:playlist:37i9dQZF1DX59NCqCqJtoH
# spotify:playlist:37i9dQZF1DWYzpSJHStHHx
# spotify:playlist:37i9dQZF1DXdQvOLqzNHSW
# spotify:playlist:37i9dQZF1DX873GaRGUmPl
# spotify:playlist:37i9dQZF1DX9LbdoYID5v7
# spotify:playlist:37i9dQZF1DXaLaoaQqrfyO
# spotify:playlist:37i9dQZF1DXdTCdwCKzXwo
# spotify:playlist:37i9dQZF1DX7HOk71GPfSw
# spotify:playlist:37i9dQZF1DX8gDIpdqp1XJ
# spotify:playlist:37i9dQZF1DX26DKvjp0s9M
# spotify:playlist:37i9dQZF1DXaLI8a395lse
# spotify:playlist:37i9dQZF1DX9B1hu73DioC
# spotify:playlist:37i9dQZF1DX1aTyQ3Z9nTc
# spotify:playlist:37i9dQZF1DWVV27DiNWxkR
# spotify:playlist:37i9dQZF1DX0YKekzl0blG
# spotify:playlist:37i9dQZF1DXa71eg5j9dKZ
# spotify:playlist:37i9dQZF1DX9myttyycIxA
# spotify:playlist:37i9dQZF1DX6ujZpAN0v9r
# spotify:playlist:37i9dQZF1DXb67OkZ6150Z

# %%
df
# Out:
#                                                  title  \
# 0                                          Without You
# 1                                                 Guys
# 2                   Say It - Spotify Studios Recording
# 3                                ALL THESE INSTRUMENTS
# 4                                            alley-oop
# ...                                                ...
# 1879                             Maps - Single Version
# 1880                                     Like a Virgin
# 1881  Cornflake Girl - Recorded At RAK Studios, London
# 1882                                      Into My Arms
# 1883            When the Party's over (Acoustic Piano)
#
#                       artist  popularity  danceability  energy  key  loudness  \
# 0             Perfume Genius           0         0.649   0.755    9    -5.330
# 1                   The 1975          55         0.384   0.579    6    -8.216
# 2                girl in red           0         0.518   0.777   10    -6.958
# 3                 Nick Hakim           0         0.642   0.523    7   -10.223
# 4                      Dijon           0         0.536   0.227   11   -14.150
# ...                      ...         ...           ...     ...  ...       ...
# 1879           Freya Ridings          36         0.389   0.124    7    -8.406
# 1880                  L'Isle          38         0.725   0.336    5   -11.828
# 1881  Florence + The Machine          52         0.537   0.589    9    -6.174
# 1882          Band of Horses          48         0.540   0.186    0   -10.167
# 1883            Ben Woodward          36         0.619   0.226    4   -13.453
#
#       mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0        1       0.0288       0.06770          0.006830    0.3460   0.8320
# 1        1       0.0295       0.00297          0.000894    0.2130   0.4350
# 2        1       0.0325       0.03280          0.000000    0.2820   0.7490
# 3        1       0.0375       0.66600          0.884000    0.3440   0.2570
# 4        1       0.3500       0.69200          0.000112    0.1120   0.5550
# ...    ...          ...           ...               ...       ...      ...
# 1879     1       0.0294       0.92000          0.000031    0.0993   0.1180
# 1880     1       0.0542       0.58300          0.002750    0.1250   0.2500
# 1881     0       0.0281       0.01770          0.000014    0.3610   0.3390
# 1882     1       0.0280       0.97900          0.036000    0.1070   0.0751
# 1883     1       0.0641       0.95900          0.000044    0.1060   0.1880
#
#         tempo                      id  duration_ms  time_signature
# 0     133.512  2SPxgEush9C8GS5RqgXdqi       155547               4
# 1     203.795  1qQJWohzIrKMNIz6pyyKYw       269929               4
# 2     171.925  4677jRCDMa05jcA94EQ0hG       173175               4
# 3     101.024  1AbDNLyJWZVPn0Q3XJNcFQ       249211               4
# 4     116.411  6IERGfMBe3csfANIuQ74D9       173978               3
# ...       ...                     ...          ...             ...
# 1879   95.460  0pqU55UfyCSLyTFHjdYqQP       149173               4
# 1880   96.961  1FaxioLjUIAGpuvkDIDQHF       207414               4
# 1881  131.272  0eJEcotVKze2Ioy4u0T7eR       281960               4
# 1882   92.186  3kodZApJaGmtZxw9gEpFki       258187               4
# 1883  124.960  1pG5nd6gmfbMwUfT5shDQe       195945               3
#
# [1884 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['title', 'artist', 'popularity', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'id', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
vector_feats = ['danceability', 'energy', 'key','loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness','liveness', 'valence', 'tempo']

# %%
vector_list = []
for i in range(len(df)):
    vector = []
    for item in vector_feats:
        vector.append(df.iloc[i][item])
    vector_list.append(vector)

# %%
## Get playlist, add genre columns, then use
